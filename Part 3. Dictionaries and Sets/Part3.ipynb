# %% [markdown]
# # **CA4. Multiprocessing**
# **Sansores Cruz Angel David\
# Data Engineering\
# Universidad Politécnica de Yucatán\
# Ucú, Yucatán, México\
# 2109139@upy.edu.mx**
#
# # Part 5. Compiling to C

# %% [markdown]
# 12. Use the marco geoestadístico 2010 (https://www.inegi.org.mx/app/biblioteca/ficha.html?upc=889463807469)     and 2020 (https://www.inegi.org.mx/app/biblioteca/ficha.html?upc=702825292812) to obtain the “Áreas Geoestadísticas Básicas”(AGEBs) from Mérida, Yucatán. AGEBs evolve on time.

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
Mex_2010 = gpd.read_file('AGEB_urb_2010_5.dbf')
Mex_2010.head()
# Out:
#     CODIGO         CVEGEO                  GEOGRAFICO FECHAACT GEOMETRIA  \
# 0  LA_6052  0100100013204  ÁREA GEOESTADÍSTICA BÁSICA  12/2007      ÁREA
# 1  LA_6052  0100100013721  ÁREA GEOESTADÍSTICA BÁSICA  12/2007      ÁREA
# 2  LA_6052  0100100010657  ÁREA GEOESTADÍSTICA BÁSICA  12/2007      ÁREA
# 3  LA_6052  0100100011528  ÁREA GEOESTADÍSTICA BÁSICA  12/2007      ÁREA
# 4  LA_6052  0100100011674  ÁREA GEOESTADÍSTICA BÁSICA  12/2007      ÁREA
#
#   INSTITUCIO  OID                                           geometry
# 0      INEGI    1  POLYGON ((2475018.434 1098724.434, 2475012.982...
# 1      INEGI    2  POLYGON ((2475469.244 1098964.293, 2475431.454...
# 2      INEGI    3  POLYGON ((2470787.576 1096193.647, 2470787.327...
# 3      INEGI    4  POLYGON ((2470709.683 1097766.390, 2470705.629...
# 4      INEGI    5  POLYGON ((2466998.954 1095069.117, 2467001.023...

# %%
# Filtering by "Clave geoestadistica concatenada"
Mex_merida_2010 = Mex_2010[Mex_2010['CVEGEO'].str.startswith('31050')]
Mex_merida_2010
# Out:
#         CODIGO         CVEGEO                  GEOGRAFICO FECHAACT GEOMETRIA  \
# 53392  LA_6052  310500001516A  ÁREA GEOESTADÍSTICA BÁSICA  12/2007      ÁREA
# 53393  LA_6052  3105000012625  ÁREA GEOESTADÍSTICA BÁSICA  12/2007      ÁREA
# 53394  LA_6052  3105000012697  ÁREA GEOESTADÍSTICA BÁSICA  12/2007      ÁREA
# 53395  LA_6052  3105000013572  ÁREA GEOESTADÍSTICA BÁSICA  12/2007      ÁREA
# 53396  LA_6052  3105000015649  ÁREA GEOESTADÍSTICA BÁSICA  12/2007      ÁREA
# ...        ...            ...                         ...      ...       ...
# 53861  LA_6052  3105001116276  ÁREA GEOESTADÍSTICA BÁSICA  09/2010      ÁREA
# 53862  LA_6052  3105001116280  ÁREA GEOESTADÍSTICA BÁSICA  09/2010      ÁREA
# 53863  LA_6052  3105001116295  ÁREA GEOESTADÍSTICA BÁSICA  09/2010      ÁREA
# 53864  LA_6052  3105004086596  ÁREA GEOESTADÍSTICA BÁSICA  06/2010      ÁREA
# 53865  LA_6052  3105004086609  ÁREA GEOESTADÍSTICA BÁSICA  06/2010      ÁREA
#
#       INSTITUCIO    OID                                           geometry
# 53392      INEGI  53393  POLYGON ((3779011.482 1044206.738, 3779006.208...
# 53393      INEGI  53394  POLYGON ((3774738.557 1051086.957, 3774742.268...
# 53394      INEGI  53395  POLYGON ((3774600.177 1053733.617, 3774614.671...
# 53395      INEGI  53396  POLYGON ((3774145.121 1052822.459, 3774195.333...
# 53396      INEGI  53397  POLYGON ((3774614.438 1051099.182, 3774607.695...
# ...          ...    ...                                                ...
# 53861      INEGI  53862  POLYGON ((3776997.723 1035039.429, 3776954.642...
# 53862      INEGI  53863  POLYGON ((3777353.490 1035299.171, 3777357.018...
# 53863      INEGI  53864  POLYGON ((3777129.513 1035511.935, 3777125.534...
# 53864      INEGI  53865  POLYGON ((3782199.467 1045432.053, 3782254.615...
# 53865      INEGI  53866  POLYGON ((3782318.635 1044582.720, 3782316.474...
#
# [474 rows x 8 columns]

# %%
Mex_2020 = gpd.read_file('31a.dbf') 
Mex_2020
# Out:
#              CVEGEO CVE_ENT CVE_MUN CVE_LOC CVE_AGEB  \
# 0     3100100010130      31     001    0001     0130
# 1     3100100010145      31     001    0001     0145
# 2     3100100010164      31     001    0001     0164
# 3     3100100010126      31     001    0001     0126
# 4     3100100010107      31     001    0001     0107
# ...             ...     ...     ...     ...      ...
# 1527  3101900630421      31     019    0063     0421
# 1528  3101900630436      31     019    0063     0436
# 1529  3101900620012      31     019    0062     0012
# 1530  3101900620031      31     019    0062     0031
# 1531  3101900620046      31     019    0062     0046
#
#                                                geometry
# 0     POLYGON ((3776847.045 1015576.473, 3776850.565...
# 1     POLYGON ((3776745.860 1015499.562, 3776745.439...
# 2     POLYGON ((3776136.004 1014614.653, 3776022.228...
# 3     POLYGON ((3776247.740 1014594.755, 3776229.182...
# 4     POLYGON ((3776613.825 1015270.341, 3776615.972...
# ...                                                 ...
# 1527  POLYGON ((3982590.953 1058734.415, 3982559.676...
# 1528  POLYGON ((3981881.868 1056993.706, 3981910.041...
# 1529  POLYGON ((3948903.252 1034634.683, 3949053.535...
# 1530  POLYGON ((3948921.666 1033345.003, 3948961.994...
# 1531  POLYGON ((3949604.040 1034771.031, 3949682.465...
#
# [1532 rows x 6 columns]

# %%
# Filtering by "Clave de Municipio" Merida, Yucatan (050)
Mex_merida_2020 = Mex_2020[Mex_2020['CVE_MUN'] == "050"]
Mex_merida_2020
# Out:
#             CVEGEO CVE_ENT CVE_MUN CVE_LOC CVE_AGEB  \
# 412  3105000015329      31     050    0001     5329
# 413  3105000012466      31     050    0001     2466
# 414  310500001249A      31     050    0001     249A
# 415  3105000015827      31     050    0001     5827
# 416  3105000014706      31     050    0001     4706
# ..             ...     ...     ...     ...      ...
# 933  3105000017039      31     050    0001     7039
# 934  3105000014049      31     050    0001     4049
# 935  3105000010864      31     050    0001     0864
# 936  310500001085A      31     050    0001     085A
# 937  3105000010879      31     050    0001     0879
#
#                                               geometry
# 412  POLYGON ((3779478.623 1047307.492, 3779480.973...
# 413  POLYGON ((3777875.435 1056949.722, 3777947.632...
# 414  POLYGON ((3779713.782 1053802.753, 3779711.800...
# 415  POLYGON ((3772091.762 1052572.146, 3772125.684...
# 416  POLYGON ((3772829.128 1047931.320, 3772821.774...
# ..                                                 ...
# 933  POLYGON ((3775406.523 1040943.870, 3775457.091...
# 934  POLYGON ((3775740.093 1048924.453, 3775743.166...
# 935  POLYGON ((3774665.953 1057517.934, 3774639.617...
# 936  POLYGON ((3772545.613 1046715.097, 3772453.186...
# 937  POLYGON ((3776405.484 1042602.499, 3776323.541...
#
# [526 rows x 6 columns]

# %% [markdown]
# Now that we have the required information, solely from Merida, Yucatan, we can start working on the sets.

# %%
# The only feature they share is the "CVEGEO" which will be our key now that we will be working with sets
set_2010 = set(Mex_merida_2010["CVEGEO"])
set_2020 = set(Mex_merida_2020["CVEGEO"])

# %% [markdown]
# # **AGEBs which remains from 2010 on 2020.**

# %%
agebs_remain = set_2010.intersection(set_2020)
print("AGEBs that remain from 2010 to 2020:")
agebs_remain
# Out:
# AGEBs that remain from 2010 to 2020:
# {'3105000010120',
#  '3105000010169',
#  '3105000010188',
#  '310500001021A',
#  '3105000010224',
#  '3105000010262',
#  '3105000010281',
#  '3105000010296',
#  '3105000010309',
#  '3105000010313',
#  '3105000010328',
#  '3105000010332',
#  '3105000010347',
#  '3105000010366',
#  '310500001039A',
#  '3105000010402',
#  '3105000010417',
#  '3105000010421',
#  '3105000010436',
#  '3105000010440',
#  '3105000010455',
#  '3105000010489',
#  '3105000010493',
#  '3105000010506',
#  '3105000010510',
#  '3105000010525',
#  '310500001053A',
#  '3105000010544',
#  '3105000010563',
#  '3105000010597',
#  '310500001060A',
#  '3105000010614',
#  '3105000010629',
#  '3105000010633',
#  '3105000010648',
#  '3105000010652',
#  '3105000010667',
#  '3105000010671',
#  '3105000010686',
#  '3105000010718',
#  '3105000010737',
#  '3105000010741',
#  '3105000010756',
#  '3105000010760',
#  '310500001078A',
#  '3105000010807',
#  '3105000010826',
#  '3105000011218',
#  '3105000011241',
#  '3105000011345',
#  '3105000011453',
#  '3105000011468',
#  '3105000011472',
#  '3105000011487',
#  '3105000011504',
#  '3105000011523',
#  '3105000011542',
#  '3105000011557',
#  '3105000011561',
#  '3105000011576',
#  '3105000011608',
#  '3105000011631',
#  '3105000011650',
#  '3105000011665',
#  '3105000011684',
#  '3105000011699',
#  '3105000011716',
#  '3105000011773',
#  '3105000011805',
#  '310500001181A',
#  '3105000011824',
#  '3105000011843',
#  '3105000011858',
#  '3105000011913',
#  '310500001199A',
#  '3105000012080',
#  '3105000012201',
#  '3105000012216',
#  '3105000012220',
#  '3105000012235',
#  '310500001224A',
#  '3105000012254',
#  '3105000012269',
#  '3105000012273',
#  '3105000012288',
#  '3105000012292',
#  '310500001231A',
#  '3105000012324',
#  '3105000012339',
#  '3105000012343',
#  '3105000012358',
#  '3105000012362',
#  '3105000012377',
#  '3105000012381',
#  '3105000012396',
#  '3105000012409',
#  '3105000012413',
#  '3105000012428',
#  '3105000012432',
#  '3105000012447',
#  '3105000012451',
#  '3105000012466',
#  '3105000012470',
#  '3105000012485',
#  '310500001249A',
#  '3105000012502',
#  '3105000012517',
#  '3105000012521',
#  '3105000012540',
#  '3105000012555',
#  '3105000012574',
#  '3105000012589',
#  '3105000012593',
#  '3105000012606',
#  '3105000012610',
#  '3105000012625',
#  '310500001263A',
#  '3105000012644',
#  '3105000012663',
#  '3105000012678',
#  '3105000012682',
#  '3105000012697',
#  '310500001270A',
#  '3105000012714',
#  '3105000012729',
#  '3105000012733',
#  '3105000012748',
#  '3105000012771',
#  '3105000012786',
#  '3105000012803',
#  '3105000012818',
#  '3105000012822',
#  '3105000012837',
#  '3105000012841',
#  '3105000012856',
#  '3105000012860',
#  '3105000012875',
#  '310500001288A',
#  '3105000012894',
#  '3105000012907',
#  '3105000012911',
#  '3105000012926',
#  '3105000012930',
#  '3105000012945',
#  '310500001295A',
#  '3105000012964',
#  '3105000012979',
#  '3105000012983',
#  '3105000012998',
#  '3105000013002',
#  '3105000013017',
#  '3105000013021',
#  '3105000013036',
#  '3105000013040',
#  '3105000013055',
#  '310500001306A',
#  '3105000013074',
#  '3105000013089',
#  '3105000013093',
#  '3105000013106',
#  '3105000013110',
#  '3105000013125',
#  '310500001313A',
#  '3105000013144',
#  '3105000013159',
#  '3105000013163',
#  '3105000013178',
#  '3105000013182',
#  '3105000013197',
#  '310500001320A',
#  '3105000013214',
#  '3105000013233',
#  '3105000013248',
#  '3105000013267',
#  '3105000013271',
#  '3105000013286',
#  '3105000013290',
#  '3105000013303',
#  '3105000013341',
#  '3105000013356',
#  '3105000013360',
#  '310500001338A',
#  '3105000013394',
#  '3105000013407',
#  '3105000013411',
#  '3105000013426',
#  '3105000013430',
#  '3105000013445',
#  '310500001345A',
#  '3105000013483',
#  '3105000013500',
#  '3105000013515',
#  '3105000013549',
#  '3105000013572',
#  '3105000013587',
#  '3105000013591',
#  '3105000013604',
#  '3105000013619',
#  '3105000013657',
#  '3105000013676',
#  '3105000013695',
#  '3105000013708',
#  '3105000013712',
#  '3105000013727',
#  '3105000013746',
#  '3105000013765',
#  '310500001377A',
#  '3105000013784',
#  '3105000013799',
#  '3105000013801',
#  '310500001384A',
#  '3105000013854',
#  '3105000013869',
#  '3105000013873',
#  '3105000013905',
#  '310500001391A',
#  '3105000013939',
#  '3105000013943',
#  '3105000013958',
#  '3105000013962',
#  '3105000013977',
#  '3105000013981',
#  '3105000013996',
#  '3105000014000',
#  '3105000014015',
#  '310500001402A',
#  '3105000014034',
#  '3105000014049',
#  '3105000014068',
#  '3105000014072',
#  '3105000014087',
#  '3105000014091',
#  '3105000014104',
#  '3105000014119',
#  '3105000014123',
#  '3105000014138',
#  '3105000014142',
#  '3105000014157',
#  '3105000014161',
#  '3105000014176',
#  '3105000014180',
#  '3105000014195',
#  '3105000014208',
#  '3105000014212',
#  '3105000014227',
#  '3105000014231',
#  '3105000014250',
#  '3105000014265',
#  '310500001427A',
#  '3105000014284',
#  '3105000014299',
#  '3105000014301',
#  '3105000014316',
#  '3105000014320',
#  '3105000014335',
#  '3105000014354',
#  '3105000014477',
#  '3105000014481',
#  '3105000014496',
#  '3105000014509',
#  '3105000014513',
#  '3105000014528',
#  '3105000014532',
#  '3105000014547',
#  '3105000014566',
#  '3105000014570',
#  '3105000014585',
#  '3105000014602',
#  '3105000014617',
#  '3105000014621',
#  '3105000014636',
#  '3105000014640',
#  '310500001466A',
#  '3105000014674',
#  '3105000014689',
#  '3105000014693',
#  '3105000014706',
#  '3105000014710',
#  '3105000014725',
#  '310500001473A',
#  '3105000014759',
#  '3105000014763',
#  '3105000014814',
#  '3105000014829',
#  '3105000014833',
#  '3105000014848',
#  '3105000014852',
#  '3105000014867',
#  '3105000014871',
#  '3105000014886',
#  '3105000014890',
#  '3105000014903',
#  '3105000014937',
#  '3105000014960',
#  '3105000014975',
#  '310500001498A',
#  '3105000014994',
#  '3105000015009',
#  '3105000015013',
#  '3105000015028',
#  '3105000015032',
#  '3105000015047',
#  '3105000015051',
#  '3105000015066',
#  '3105000015070',
#  '3105000015085',
#  '310500001509A',
#  '3105000015102',
#  '3105000015117',
#  '3105000015121',
#  '3105000015136',
#  '3105000015140',
#  '3105000015155',
#  '310500001516A',
#  '3105000015174',
#  '3105000015189',
#  '3105000015210',
#  '3105000015225',
#  '310500001523A',
#  '3105000015244',
#  '3105000015259',
#  '3105000015263',
#  '3105000015278',
#  '3105000015282',
#  '3105000015297',
#  '310500001530A',
#  '3105000015314',
#  '3105000015329',
#  '3105000015333',
#  '3105000015348',
#  '3105000015386',
#  '3105000015390',
#  '3105000015418',
#  '3105000015422',
#  '3105000015437',
#  '3105000015441',
#  '3105000015456',
#  '3105000015460',
#  '3105000015475',
#  '310500001548A',
#  '3105000015494',
#  '3105000015511',
#  '3105000015526',
#  '3105000015579',
#  '3105000015583',
#  '3105000015598',
#  '3105000015600',
#  '310500001562A',
#  '3105000015634',
#  '3105000015649',
#  '3105000015672',
#  '3105000015687',
#  '3105000015691',
#  '3105000015704',
#  '3105000015719',
#  '3105000015723',
#  '3105000015738',
#  '3105000015742',
#  '3105000015757',
#  '3105000015761',
#  '3105000015776',
#  '3105000015780',
#  '3105000015795',
#  '3105000015808',
#  '3105000015812',
#  '3105000015827',
#  '3105000015831',
#  '3105000015846',
#  '3105000015850',
#  '3105000015865',
#  '310500001587A',
#  '3105000015884',
#  '3105000015899',
#  '3105000015916',
#  '3105000015920',
#  '3105000015935',
#  '310500001594A',
#  '3105000015969',
#  '3105000015973',
#  '3105000015988',
#  '3105000015992',
#  '3105000016007',
#  '3105000016030',
#  '3105000016045',
#  '310500001605A',
#  '3105000016064',
#  '3105000016079',
#  '3105000016083',
#  '3105000016098',
#  '3105000016100',
#  '3105000016115',
#  '310500001612A',
#  '3105000016134',
#  '3105000016149',
#  '3105000016153',
#  '3105000016168',
#  '3105000016172',
#  '3105000016187',
#  '3105000016191',
#  '3105000016204',
#  '3105000016219',
#  '3105000016223',
#  '3105000016238',
#  '3105000016242',
#  '3105000016257',
#  '3105000016261',
#  '3105000016350',
#  '3105000016365',
#  '310500001637A',
#  '3105000016384',
#  '3105000016399',
#  '3105000016401',
#  '3105000016416',
#  '3105000016420',
#  '3105000016435',
#  '310500001644A',
#  '3105000016454',
#  '3105000016469',
#  '3105000016473',
#  '3105000016488',
#  '3105000016492',
#  '3105000016505',
#  '310500001651A',
#  '3105000016524',
#  '3105000016539',
#  '3105000016543',
#  '3105000016558',
#  '3105000016581',
#  '310500075441A',
#  '3105000754424',
#  '3105000754439',
#  '3105000754443',
#  '3105000754458',
#  '3105000755564',
#  '3105000756011',
#  '3105000756026',
#  '3105000756562',
#  '3105000756577',
#  '3105000774388',
#  '3105000774392',
#  '3105000774941',
#  '3105000774956',
#  '3105000775530',
#  '3105000776312',
#  '3105000776327',
#  '3105000776331',
#  '3105000842184',
#  '3105000842199',
#  '3105000843568',
#  '3105000844053',
#  '3105000844373',
#  '3105000845193',
#  '3105000845206',
#  '3105000845545',
#  '3105000845954',
#  '3105000846308',
#  '3105000932127',
#  '3105000933816',
#  '3105000933820',
#  '310500093555A',
#  '3105000935653',
#  '3105000935668',
#  '3105000936346',
#  '3105001114405',
#  '3105001116276',
#  '3105001116280',
#  '3105001116295'}

# %%
filtered_agebs_2020 = Mex_merida_2020[Mex_merida_2020['CVEGEO'].isin(agebs_remain)]

fig, ax = plt.subplots(figsize=(15, 15))
filtered_agebs_2020.plot(ax=ax, color='pink', edgecolor='black')
plt.title('AGEBs that Remain from 2010 to 2020')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()

# %% [markdown]
# # **New AGEBs on 2020.**

# %%
new_agebs_2020 = set_2020.difference(set_2010)
print("\nNew AGEBs 2020:")
new_agebs_2020
# Out:
# New AGEBs 2020:
# {'3105000010027',
#  '3105000010031',
#  '3105000010154',
#  '3105000010277',
#  '3105000010474',
#  '3105000010559',
#  '3105000010845',
#  '310500001085A',
#  '3105000010864',
#  '3105000010879',
#  '3105000014462',
#  '3105000014744',
#  '3105000014778',
#  '3105000016613',
#  '3105000016628',
#  '3105000016632',
#  '3105000016647',
#  '3105000016651',
#  '3105000016666',
#  '3105000016670',
#  '310500001669A',
#  '3105000016702',
#  '3105000016717',
#  '3105000016721',
#  '3105000016736',
#  '3105000016740',
#  '3105000016755',
#  '310500001676A',
#  '3105000016774',
#  '3105000016789',
#  '3105000016793',
#  '3105000016806',
#  '3105000016810',
#  '3105000016825',
#  '310500001683A',
#  '3105000016844',
#  '3105000016859',
#  '3105000016863',
#  '3105000016878',
#  '3105000016882',
#  '3105000016897',
#  '310500001690A',
#  '3105000016914',
#  '3105000016929',
#  '3105000016948',
#  '3105000016952',
#  '3105000016967',
#  '3105000016971',
#  '3105000016986',
#  '3105000016990',
#  '3105000017005',
#  '310500001701A',
#  '3105000017024',
#  '3105000017039',
#  '3105000017043',
#  '3105000845352',
#  '3105000845367',
#  '3105000846933',
#  '3105000930135'}

# %%
fig, ax = plt.subplots(figsize=(15, 15))
Mex_merida_2020[Mex_merida_2020["CVEGEO"].isin(new_agebs_2020)].plot(ax=ax, color='pink', alpha=0.5, label='Nuevos AGEBs en 2020')
plt.title('New AGEBs 2020')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# # **AGEBs that disappear from 2010 to 2020.**

# %%
agebs_disappear = set_2010.difference(set_2020)
print("\nAGEBs that disappear from 2010 to 2020:")
agebs_disappear
# Out:
# AGEBs that disappear from 2010 to 2020:
# {'3105000012752',
#  '3105000012767',
#  '3105000013534',
#  '3105000013835',
#  '3105000015507',
#  '3105004086596',
#  '3105004086609'}

# %%
fig, ax = plt.subplots(figsize=(15, 15))
Mex_merida_2010[Mex_merida_2010["CVEGEO"].isin(agebs_disappear)].plot(ax=ax, color='red', alpha=0.5, label='AGEBs que desaparecen')
plt.title('AGEBs that disappear from 2010 to 2020')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# Create the plot
fig, ax = plt.subplots(figsize=(15, 15))

# Plot the AGEBs that remain from 2010 to 2020 (agebs_remain)
Mex_merida_2020[Mex_merida_2020['CVEGEO'].isin(agebs_remain)].plot(ax=ax, color='pink', edgecolor='black', label='Remain from 2010')

# Plot the new AGEBs in 2020 (new_agebs_2020)
Mex_merida_2020[Mex_merida_2020['CVEGEO'].isin(new_agebs_2020)].plot(ax=ax, color='red', edgecolor='black', label='New in 2020')

# Plot the AGEBs that disappeared from 2010 to 2020 (disappeared_agebs)
Mex_merida_2010[~Mex_merida_2010['CVEGEO'].isin(agebs_remain)].plot(ax=ax, color='purple', edgecolor='black', label='Disappeared by 2020')

# Adding legend and titles
plt.legend()
plt.title('AGEBs: Remain, New, and Disappeared')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
